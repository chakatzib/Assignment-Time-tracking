# %% [markdown]
# # Programming Project 1 analysis using EDA tools
# - Name:Joey
# - Date:10/3/2023
# - Version: 1

# %% [markdown]
# ### Import Modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import seaborn as sns

# %% [markdown]
# ### Load the dataset and save it to a dataframe named 'df'
# ![image.png](attachment:image.png)

# %%
df=pd.read_csv('scheduleproject1.csv')

# %%
df.head()
# Out:
#   INITIALS       DATE   COURSE_ID  TIME(MINUTES)         SUMMARY
# 0        JG  9/5/2023    DS160-01             75      Did Excel
# 1        JG  9/5/2023  MATH205-03             90           Stats
# 2        JG  9/5/2023  MUSE123-05             75            Band
# 3        JG  9/6/2023    DS160-01            120    Podcast work
# 4        JG  9/6/2023  ECON110-03             75  Macroeconomics

# %% [markdown]
# ### Investigate your dataset

# %%
df.head()
# Out:
#   INITIALS       DATE   COURSE_ID  TIME(MINUTES)         SUMMARY
# 0        JG  9/5/2023    DS160-01             75      Did Excel
# 1        JG  9/5/2023  MATH205-03             90           Stats
# 2        JG  9/5/2023  MUSE123-05             75            Band
# 3        JG  9/6/2023    DS160-01            120    Podcast work
# 4        JG  9/6/2023  ECON110-03             75  Macroeconomics

# %%
df.tail()
# Out:
#    INITIALS        DATE   COURSE_ID  TIME(MINUTES)  \
# 22       NaN  9/25/2023  MUSE137-01             45
# 23        JG  9/25/2023  ECON110-03              0
# 24        JG  9/26/2023    DS160-01             75
# 25        JG  9/26/2023  MUSE123-05             75
# 26       NaN  9/26/2023  MATH205-03             90
#
#                          SUMMARY
# 22                Brass ensemble
# 23        Test in testing center
# 24  Dataset work with matplotlib
# 25                          band
# 26                    Stats quiz

# %%
df.sample()
# Out:
#    INITIALS        DATE   COURSE_ID  TIME(MINUTES) SUMMARY
# 21        JG  9/21/2023  MUSE123-05             75     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   INITIALS       25 non-null     object
#  1   DATE           27 non-null     object
#  2   COURSE_ID      27 non-null     object
#  3   TIME(MINUTES)  27 non-null     int64
#  4   SUMMARY        15 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.2+ KB

# %% [markdown]
# ### Summary Statistics
# Calculate basic statistics for the 'Time (minutes)' column, such as mean, median, minimum, and maximum. This will give you an overview of how time is distributed across activities. use table and graphical representations
# ![image.png](attachment:image.png)

# %%
df.columns
# Out:
# Index(['INITIALS ', 'DATE', 'COURSE_ID', 'TIME(MINUTES)', 'SUMMARY'], dtype='object')

# %%
df.describe()
# Out:
#        TIME(MINUTES)
# count      27.000000
# mean       76.851852
# std        20.900320
# min         0.000000
# 25%        75.000000
# 50%        75.000000
# 75%        90.000000
# max       120.000000

# %%
raw_data=pd.read_csv("scheduleproject1.csv")
sns.boxplot(x='COURSE_ID',y='TIME(MINUTES)',data=raw_data)
raw_data["TIME(MINUTES)"].describe
# Out:
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <bound method NDFrame.describe of 0      75
# 1      90
# 2      75
# 3     120
# 4      75
# 5      75
# 6      90
# 7      45
# 8      75
# 9      85
# 10     75
# 11     90
# ...

# %% [markdown]
# ### Create two new columns "day" and "day_name" using the "Date" column in which the day will represent the range of days
# ![image.png](attachment:image.png)

# %%
df['DATE']=pd.to_datetime(df['DATE'])
df['day_name']=df['DATE'].dt.day_name()
df['day']=range(1,len(df)+1)
df.head()
# Out:
#   INITIALS        DATE   COURSE_ID  TIME(MINUTES)         SUMMARY   day_name  \
# 0        JG 2023-09-05    DS160-01             75      Did Excel     Tuesday
# 1        JG 2023-09-05  MATH205-03             90           Stats    Tuesday
# 2        JG 2023-09-05  MUSE123-05             75            Band    Tuesday
# 3        JG 2023-09-06    DS160-01            120    Podcast work  Wednesday
# 4        JG 2023-09-06  ECON110-03             75  Macroeconomics  Wednesday
#
#    day
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %% [markdown]
# ### Data Visualization:
# 1. Create a histogram to visually represent the distribution of time spent.
# 2. Create a  bar chart to visually represent the distribution of time spent on different courses and comment on the course you spent most and least time
# ![image-3.png](attachment:image-3.png)

# %%
sns.histplot(x="TIME(MINUTES)",data=raw_data)
# Out:
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='TIME(MINUTES)', ylabel='Count'>

# %%
sns.barplot(x='COURSE_ID',y='TIME(MINUTES)',data=raw_data)
# Out:
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='COURSE_ID', ylabel='TIME(MINUTES)'>

# %%
# I spent the most time on theology, math, and data science, and least in music.

# %% [markdown]
# ### Activity Counts:
#
# Count the occurrences of each course in the dataset to see how often you engaged in each.

# %%
df["COURSE_ID"].value_counts()
# Out:
# COURSE_ID
# DS160-01      8
# ECON110-03    6
# MATH205-03    5
# MUSE123-05    3
# THEO200-05    3
# MUSE137-01    2
# Name: count, dtype: int64

# %% [markdown]
# ### Time Trends:
#
# Plot a line chart to visualize how time spent on activities changes over the observed days.
# ![image.png](attachment:image.png)

# %%
df.columns
# Out:
# Index(['INITIALS ', 'DATE', 'COURSE_ID', 'TIME(MINUTES)', 'SUMMARY',
#        'day_name', 'day'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   INITIALS       25 non-null     object
#  1   DATE           27 non-null     datetime64[ns]
#  2   COURSE_ID      27 non-null     object
#  3   TIME(MINUTES)  27 non-null     int64
#  4   SUMMARY        15 non-null     object
#  5   day_name       27 non-null     object
#  6   day            27 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 1.6+ KB

# %%
sns.set(rc={'figure.figsize':(12,10)})

sns.lineplot(x='day',
             y="TIME(MINUTES)",
             data=df,
             hue='COURSE_ID')
# Out:
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jguth\anaconda3\envs\DS160-01\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### Course Analysis:
#
# For each course ex.(DS 160, CS 150, CS 440), calculate the total time spent. Which course received the most time, and which received the least?
# - Sample print statement: Total time spent on CS160: 180 min

# %%
ds160=df.query('COURSE_ID=="DS160-01"')['TIME(MINUTES)'].sum()
print(f"Total time spent on DS160: {ds160}")
#DS160 has recieved the most time. MUSE137 recieved the least.
# Out:
# Total time spent on DS160: 660

# %%
math205=df.query('COURSE_ID=="MATH205-03"')['TIME(MINUTES)'].sum()
print(f"Total time spent on MATH205: {math205}")
# Out:
# Total time spent on MATH205:450

# %%
muse123=df.query('COURSE_ID=="MUSE123-05"')['TIME(MINUTES)'].sum()
print(f"Total time spent on MUSE123: {muse123}")
# Out:
# Total time spent on MUSE123: 225

# %%
econ110=df.query('COURSE_ID=="ECON110-03"')['TIME(MINUTES)'].sum()
print(f"Total time spent on ECON110: {econ110}")
# Out:
# Total time spent on ECON110: 390

# %%
muse137=df.query('COURSE_ID=="MUSE137-01"')['TIME(MINUTES)'].sum()
print(f"Total time spent on MUSE137: {muse137}")
# Out:
# Total time spent on MUSE137: 90

# %%
theo200=df.query('COURSE_ID=="THEO200-05"')['TIME(MINUTES)'].sum()
print(f"Total time spent on THEO200: {theo200}")
# Out:
# Total time spent on THEO200: 260

# %% [markdown]
# ### Correlations:
# - Examine whether there are any correlations between the day and the time spent. For example, do you spend more time on courses over days or less.
# ![image.png](attachment:image.png)

# %%
heat_map=df[['day','TIME(MINUTES)']].corr(method='pearson')
cols=['day','TIME(MINUTES)']
sns.heatmap(heat_map, xticklabels=cols, yticklabels=cols, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Findings #
# The data in many of the graphs is strange looking but technically correct in regards to its source material; I have been struggling to keep the excel spreadsheet updated accurately, so this is what is responsible for the data looking strange. Time spent doesnt seem to have any real correlation with day.
